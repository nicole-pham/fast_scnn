# %%
import torch
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.nn import CrossEntropyLoss
import torchvision.transforms.functional as F
import numbers
import numpy as np
 
from train import Trainer
from model import FastSCNN
from dataset import PostdamDataset
from metrics import pixel_accuracy

# %%
num_epochs = 3
batch_size = 2
learning_rate = 0.001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device {device}")

ClassesColors = {
    (255, 255, 255): 0, # impervious_surfaces
    (0, 0, 255): 1, # building
    (0, 255, 255): 2, # low_vegetation
    (0, 255, 0): 3, # tree
    (255, 255, 0): 4, # car
    (255, 0, 0): 5 # background
    }
# Out:
# Device cuda

# %%
def get_class_color(color):
    try:
        return ClassesColors[color]
    except KeyError:
        r, g, b = color
        if r > 200 and g > 200 and b > 200:
            return 0
        elif r < 50 and g < 50 and b > 200:
            return 1
        elif r < 50 and g > 200 and b > 200:
            return 2
        elif r < 50 and g > 200 and b < 50:
            return 3
        elif r > 200 and g > 200 and b < 50:
            return 4
        else:
            return 5

def to_class_labels(segmented_image):
    w, h = segmented_image.size
    ret = torch.zeros((h, w) , dtype=torch.long)
    print("start ", w, h)
    counter = 0
    for i in range(w):
        for j in range(h):
            color = segmented_image.getpixel((i, j))
            try:
                if counter % 100000 == 0:
                    print(".", end='')
                ret[j,i] = get_class_color(color)
                #closest_color = min(list(ClassesColors.keys()), key=lambda x: np.linalg.norm(np.subtract(x, color)))
                #ret[j,i] = ClassesColors[closest_color]
                #ret[j, i] = ClassesColors[color]
                counter += 1
            except KeyError:
                print(f"Error color {closest_color} not im color mapping on {j},{i}, originial color: {color}")
                ret[j, i] = 5
    print("finish")
    return ret


class ToClassLabels(object):
    def __call__(self, segmented_image):
        if torch.is_tensor(segmented_image):
            return segmented_image
        w, h = segmented_image.size
        ret = torch.zeros((h, w), dtype=torch.long)
        for i in range(w):
            for j in range(h):
                color = segmented_image.getpixel((i, j))
                ret[j, i] = get_class_color(color)
                # closest_color = min(list(ClassesColors.keys()), key=lambda x: np.linalg.norm(np.subtract(x, color)))
                # ret[j,i] = ClassesColors[closest_color]
                # ret[j, i] = ClassesColors[color]
        return ret

class NewPad(object):
    def __init__(self, fill=0, padding_mode='constant'):
        assert isinstance(fill, (numbers.Number, str, tuple))
        assert padding_mode in ['constant', 'edge', 'reflect', 'symmetric']

        self.fill = fill
        self.padding_mode = padding_mode

    def __call__(self, img):
        """
        Args:
            img (PIL Image): img to be padded.

        Returns:
            Padded image.
        """
        if torch.is_tensor(img):
            assert img.shape == (3, 1024, 2048)
            return img
        return transforms.functional.pad(img, get_padding(img), self.fill, self.padding_mode)

    def __repr__(self):
        return self.__class__.__name__ + '(padding={0}, fill={1}, padding_mode={2})'. \
            format(self.fill, self.padding_mode)
    

# def get_padding(image):    
#     image_w, image_h = image.size
#     width = 2048
#     height= 1024
#     w_padding = width - image_w
#     h_padding = height - image_h
#     l_pad = r_pad = w_padding // 2 
#     r_pad = width - (image_w + r_pad + l_pad)
#     t_pad = b_pad = h_padding // 2 
#     b_pad = height - (image_h + t_pad + b_pad)
#     padding = (int(l_pad), int(t_pad), int(r_pad), int(b_pad))
#     return padding
# 
# class NewPad(object):
#     def __init__(self, fill=0, padding_mode='constant'):
#         assert isinstance(fill, (numbers.Number, str, tuple))
#         assert padding_mode in ['constant', 'edge', 'reflect', 'symmetric']
# 
#         self.fill = fill
#         self.padding_mode = padding_mode
#         
#     def __call__(self, img):
#         """
#         Args:
#             img (PIL Image): Image to be padded.
# 
#         Returns:
#             PIL Image: Padded image.
#         """
#         return F.pad(img, get_padding(img), self.fill, self.padding_mode)
#     
#     def __repr__(self):
#         return self.__class__.__name__ + '(padding={0}, fill={1}, padding_mode={2})'.\
#             format(self.fill, self.padding_mode)


def preprocessing(image, mask):
    mask_transformer = transforms.Compose([
        NewPad(fill=(255,0,0)),
        transforms.Lambda(lambda x: to_class_labels(x))
    ])
    image_transformer = transforms.Compose([
        NewPad(),
        transforms.ToTensor(),
        transforms.Normalize([0.3396, 0.3628, 0.3362], [0.1315, 0.1287, 0.1333])
    ])
    
    return image_transformer(image).float(), mask_transformer(mask)

# %%
train_image_path = './data/2_Ortho_RGB_train/'
train_label_path = './data/labels_train/'
test_image_path = './data/2_Ortho_RGB_test/'
test_label_path = './data/labels_test/'

ds_train = PostdamDataset(train_image_path, train_label_path, transform=preprocessing)
ds_test = PostdamDataset(test_image_path, test_label_path, transform=preprocessing)
dl_train = DataLoader(ds_train, batch_size, shuffle=True)
dl_test = DataLoader(ds_test, batch_size, shuffle=False)

img, mask = ds_train[2]
print(mask.dtype)
# Out:
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_12_RGB_box5.tif
# image name op_potsdam_3_12_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_3_12_label_box5.tif
# start  2048 1024
# .....................finish
# torch.int64

# %%
model = FastSCNN(num_classes=6)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = CrossEntropyLoss()
success_metric = pixel_accuracy
trainer = Trainer(model, criterion, optimizer, success_metric, device, None)
fit_res = trainer.fit(dl_train,
                      dl_test,
                      num_epochs= num_epochs,
                      checkpoints='src/saved_models/' + model.__class__.__name__)

print(fit_res)
# Out:
# --- EPOCH 1/3 ---
# 1587569221.9212618
# train_batch:   0%|          | 0/95 [00:00<?, ?it/s]img in ./data/2_Ortho_RGB_train/op_potsdam_7_10_RGB_box2.tif
# image name op_potsdam_7_10_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_10_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_10_RGB_box2.tif
# image name op_potsdam_5_10_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_5_10_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_7_RGB_box2.tif
# image name op_potsdam_6_7_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_7_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_9_RGB_box1.tif
# image name op_potsdam_6_9_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_9_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_9_RGB_box2.tif
# image name op_potsdam_6_9_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_9_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_12_RGB_box3.tif
# image name op_potsdam_6_12_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_12_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_13_RGB_box4.tif
# image name op_potsdam_7_13_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_7_13_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_12_RGB_box5.tif
# image name op_potsdam_6_12_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_12_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_8_RGB_box5.tif
# image name op_potsdam_7_8_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_7_8_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_10_RGB_box4.tif
# image name op_potsdam_7_10_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_7_10_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_10_RGB_box3.tif
# image name op_potsdam_6_10_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_10_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_13_RGB_box1.tif
# image name op_potsdam_4_13_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_4_13_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_8_RGB_box4.tif
# image name op_potsdam_6_8_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_8_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_11_RGB_box1.tif
# image name op_potsdam_7_11_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_7_11_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_14_RGB_box1.tif
# image name op_potsdam_5_14_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_5_14_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_7_RGB_box4.tif
# image name op_potsdam_6_7_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_7_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_14_RGB_box5.tif
# image name op_potsdam_6_14_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_14_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_11_RGB_box2.tif
# image name op_potsdam_5_11_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_5_11_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_10_RGB_box5.tif
# image name op_potsdam_2_10_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_2_10_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_8_RGB_box2.tif
# image name op_potsdam_6_8_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_8_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_11_RGB_box5.tif
# image name op_potsdam_4_11_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_4_11_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_9_RGB_box4.tif
# image name op_potsdam_6_9_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_9_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_15_RGB_box3.tif
# image name op_potsdam_6_15_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_15_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_12_RGB_box2.tif
# image name op_potsdam_5_12_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_5_12_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_15_RGB_box4.tif
# image name op_potsdam_4_15_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_4_15_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_7_RGB_box3.tif
# image name op_potsdam_6_7_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_7_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_13_RGB_box4.tif
# image name op_potsdam_2_13_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_2_13_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_8_RGB_box3.tif
# image name op_potsdam_6_8_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_8_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_15_RGB_box2.tif
# image name op_potsdam_4_15_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_4_15_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_10_RGB_box2.tif
# image name op_potsdam_2_10_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_2_10_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_9_RGB_box3.tif
# image name op_potsdam_7_9_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_7_9_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_14_RGB_box5.tif
# image name op_potsdam_5_14_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_5_14_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_11_RGB_box3.tif
# image name op_potsdam_4_11_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_4_11_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_12_RGB_box5.tif
# image name op_potsdam_2_12_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_2_12_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_12_RGB_box2.tif
# image name op_potsdam_3_12_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_3_12_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_14_RGB_box4.tif
# image name op_potsdam_3_14_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_3_14_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_15_RGB_box2.tif
# image name op_potsdam_6_15_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_15_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_12_RGB_box3.tif
# image name op_potsdam_4_12_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_4_12_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_7_RGB_box4.tif
# image name op_potsdam_7_7_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_7_7_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_11_RGB_box2.tif
# image name op_potsdam_6_11_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_11_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_15_RGB_box1.tif
# image name op_potsdam_6_15_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_15_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_12_RGB_box2.tif
# image name op_potsdam_4_12_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_4_12_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_11_RGB_box3.tif
# image name op_potsdam_2_11_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_2_11_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_15_RGB_box3.tif
# image name op_potsdam_4_15_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_4_15_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_13_RGB_box2.tif
# image name op_potsdam_5_13_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_5_13_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_15_RGB_box2.tif
# image name op_potsdam_5_15_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_5_15_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_8_RGB_box4.tif
# image name op_potsdam_7_8_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_7_8_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_8_RGB_box1.tif
# image name op_potsdam_6_8_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_8_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_14_RGB_box1.tif
# image name op_potsdam_4_14_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_4_14_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_11_RGB_box5.tif
# image name op_potsdam_2_11_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_2_11_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_11_RGB_box5.tif
# image name op_potsdam_7_11_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_7_11_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_11_RGB_box4.tif
# image name op_potsdam_7_11_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_7_11_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_13_RGB_box1.tif
# image name op_potsdam_7_13_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_7_13_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_10_RGB_box5.tif
# image name op_potsdam_6_10_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_10_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_15_RGB_box1.tif
# image name op_potsdam_5_15_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_5_15_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_13_RGB_box4.tif
# image name op_potsdam_3_13_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_3_13_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_11_RGB_box2.tif
# image name op_potsdam_4_11_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_4_11_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_13_RGB_box4.tif
# image name op_potsdam_5_13_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_5_13_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_14_RGB_box3.tif
# image name op_potsdam_3_14_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_3_14_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_13_RGB_box3.tif
# image name op_potsdam_7_13_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_7_13_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_12_RGB_box4.tif
# image name op_potsdam_5_12_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_5_12_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_15_RGB_box3.tif
# image name op_potsdam_5_15_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_5_15_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_8_RGB_box3.tif
# image name op_potsdam_7_8_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_7_8_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_7_RGB_box1.tif
# image name op_potsdam_6_7_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_7_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_12_RGB_box1.tif
# image name op_potsdam_2_12_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_2_12_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_12_RGB_box1.tif
# image name op_potsdam_5_12_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_5_12_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_14_RGB_box1.tif
# image name op_potsdam_3_14_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_3_14_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_10_RGB_box1.tif
# image name op_potsdam_6_10_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_10_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_14_RGB_box4.tif
# image name op_potsdam_5_14_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_5_14_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_12_RGB_box1.tif
# image name op_potsdam_3_12_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_3_12_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_13_RGB_box5.tif
# image name op_potsdam_2_13_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_2_13_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_10_RGB_box4.tif
# image name op_potsdam_5_10_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_5_10_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_11_RGB_box4.tif
# image name op_potsdam_2_11_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_2_11_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_9_RGB_box1.tif
# image name op_potsdam_7_9_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_7_9_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_12_RGB_box1.tif
# image name op_potsdam_7_12_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_7_12_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_13_RGB_box2.tif
# image name op_potsdam_3_13_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_3_13_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_10_RGB_box2.tif
# image name op_potsdam_6_10_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_10_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_9_RGB_box4.tif
# image name op_potsdam_7_9_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_7_9_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_7_RGB_box5.tif
# image name op_potsdam_6_7_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_7_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_10_RGB_box4.tif
# image name op_potsdam_3_10_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_3_10_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_12_RGB_box2.tif
# image name op_potsdam_7_12_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_12_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_14_RGB_box5.tif
# image name op_potsdam_2_14_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_2_14_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_10_RGB_box1.tif
# image name op_potsdam_3_10_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_3_10_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_12_RGB_box5.tif
# image name op_potsdam_7_12_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_7_12_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_11_RGB_box5.tif
# image name op_potsdam_3_11_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_3_11_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_14_RGB_box4.tif
# image name op_potsdam_4_14_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_4_14_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_11_RGB_box1.tif
# image name op_potsdam_5_11_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_5_11_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_12_RGB_box3.tif
# image name op_potsdam_5_12_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_5_12_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_12_RGB_box2.tif
# image name op_potsdam_2_12_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_2_12_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_14_RGB_box2.tif
# image name op_potsdam_3_14_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_3_14_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_11_RGB_box4.tif
# image name op_potsdam_3_11_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_3_11_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_11_RGB_box2.tif
# image name op_potsdam_7_11_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_11_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_9_RGB_box3.tif
# image name op_potsdam_6_9_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_9_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_13_RGB_box4.tif
# image name op_potsdam_6_13_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_13_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_10_RGB_box5.tif
# image name op_potsdam_7_10_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_7_10_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_10_RGB_box3.tif
# image name op_potsdam_5_10_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_5_10_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_11_RGB_box2.tif
# image name op_potsdam_3_11_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_3_11_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_13_RGB_box2.tif
# image name op_potsdam_7_13_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_13_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_13_RGB_box3.tif
# image name op_potsdam_6_13_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_13_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_12_RGB_box4.tif
# image name op_potsdam_6_12_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_12_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_7_RGB_box1.tif
# image name op_potsdam_7_7_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_7_7_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_13_RGB_box1.tif
# image name op_potsdam_2_13_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_2_13_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_7_RGB_box5.tif
# image name op_potsdam_7_7_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_7_7_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_10_RGB_box4.tif
# image name op_potsdam_6_10_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_10_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_11_RGB_box4.tif
# image name op_potsdam_6_11_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_11_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_12_RGB_box1.tif
# image name op_potsdam_6_12_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_12_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_11_RGB_box1.tif
# image name op_potsdam_3_11_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_3_11_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_10_RGB_box4.tif
# image name op_potsdam_4_10_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_4_10_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_13_RGB_box1.tif
# image name op_potsdam_6_13_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_13_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_13_RGB_box3.tif
# image name op_potsdam_5_13_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_5_13_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_12_RGB_box4.tif
# image name op_potsdam_2_12_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_2_12_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_14_RGB_box1.tif
# image name op_potsdam_2_14_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_2_14_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_13_RGB_box5.tif
# image name op_potsdam_6_13_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_13_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_10_RGB_box5.tif
# image name op_potsdam_5_10_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_5_10_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_10_RGB_box3.tif
# image name op_potsdam_4_10_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_4_10_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_13_RGB_box1.tif
# image name op_potsdam_3_13_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_3_13_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_8_RGB_box1.tif
# image name op_potsdam_7_8_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_7_8_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_13_RGB_box5.tif
# image name op_potsdam_5_13_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_5_13_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_11_RGB_box2.tif
# image name op_potsdam_2_11_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_2_11_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_10_RGB_box2.tif
# image name op_potsdam_4_10_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_4_10_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_11_RGB_box3.tif
# image name op_potsdam_7_11_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_7_11_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_15_RGB_box5.tif
# image name op_potsdam_6_15_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_15_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_12_RGB_box2.tif
# image name op_potsdam_6_12_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_12_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_14_RGB_box5.tif
# image name op_potsdam_4_14_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_4_14_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_11_RGB_box4.tif
# image name op_potsdam_4_11_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_4_11_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_14_RGB_box2.tif
# image name op_potsdam_5_14_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_5_14_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_14_RGB_box3.tif
# image name op_potsdam_6_14_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_14_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_11_RGB_box3.tif
# image name op_potsdam_5_11_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_5_11_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_14_RGB_box3.tif
# image name op_potsdam_2_14_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_2_14_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_14_RGB_box4.tif
# image name op_potsdam_2_14_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_2_14_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_13_RGB_box2.tif
# image name op_potsdam_4_13_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_4_13_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_13_RGB_box2.tif
# image name op_potsdam_2_13_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_2_13_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_7_RGB_box3.tif
# image name op_potsdam_7_7_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_7_7_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_13_RGB_box2.tif
# image name op_potsdam_6_13_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_13_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_10_RGB_box1.tif
# image name op_potsdam_5_10_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_5_10_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_7_RGB_box2.tif
# image name op_potsdam_7_7_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_7_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_11_RGB_box3.tif
# image name op_potsdam_3_11_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_3_11_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_12_RGB_box3.tif
# image name op_potsdam_7_12_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_7_12_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_12_RGB_box4.tif
# image name op_potsdam_7_12_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_7_12_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_12_RGB_box3.tif
# image name op_potsdam_2_12_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_2_12_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_10_RGB_box2.tif
# image name op_potsdam_3_10_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_3_10_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_13_RGB_box1.tif
# image name op_potsdam_5_13_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_5_13_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_15_RGB_box4.tif
# image name op_potsdam_5_15_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_5_15_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_8_RGB_box5.tif
# image name op_potsdam_6_8_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_8_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_10_RGB_box3.tif
# image name op_potsdam_3_10_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_3_10_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_14_RGB_box5.tif
# image name op_potsdam_3_14_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_3_14_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_12_RGB_box5.tif
# image name op_potsdam_4_12_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_4_12_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_13_RGB_box3.tif
# image name op_potsdam_2_13_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_2_13_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_12_RGB_box4.tif
# image name op_potsdam_3_12_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_3_12_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_10_RGB_box5.tif
# image name op_potsdam_4_10_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_4_10_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_12_RGB_box5.tif
# image name op_potsdam_3_12_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_3_12_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_15_RGB_box5.tif
# image name op_potsdam_5_15_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_5_15_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_9_RGB_box2.tif
# image name op_potsdam_7_9_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_9_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_15_RGB_box4.tif
# image name op_potsdam_6_15_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_15_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_12_RGB_box5.tif
# image name op_potsdam_5_12_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_5_12_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_14_RGB_box2.tif
# image name op_potsdam_6_14_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_14_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_13_RGB_box5.tif
# image name op_potsdam_3_13_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_3_13_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_9_RGB_box5.tif
# image name op_potsdam_6_9_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_9_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_11_RGB_box1.tif
# image name op_potsdam_2_11_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_2_11_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_11_RGB_box4.tif
# image name op_potsdam_5_11_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_5_11_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_10_RGB_box1.tif
# image name op_potsdam_7_10_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_7_10_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_11_RGB_box1.tif
# image name op_potsdam_6_11_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_11_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_11_RGB_box3.tif
# image name op_potsdam_6_11_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_6_11_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_10_RGB_box1.tif
# image name op_potsdam_4_10_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_4_10_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_14_RGB_box3.tif
# image name op_potsdam_5_14_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_5_14_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_12_RGB_box4.tif
# image name op_potsdam_4_12_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_4_12_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_15_RGB_box1.tif
# image name op_potsdam_4_15_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_4_15_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_11_RGB_box1.tif
# image name op_potsdam_4_11_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_4_11_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_10_RGB_box1.tif
# image name op_potsdam_2_10_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_2_10_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_13_RGB_box5.tif
# image name op_potsdam_7_13_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_7_13_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_10_RGB_box3.tif
# image name op_potsdam_7_10_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_7_10_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_13_RGB_box3.tif
# image name op_potsdam_4_13_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_4_13_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_13_RGB_box5.tif
# image name op_potsdam_4_13_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_4_13_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_14_RGB_box2.tif
# image name op_potsdam_4_14_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_4_14_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_11_RGB_box5.tif
# image name op_potsdam_6_11_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_11_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_10_RGB_box5.tif
# image name op_potsdam_3_10_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_3_10_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_14_RGB_box3.tif
# image name op_potsdam_4_14_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_4_14_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_10_RGB_box4.tif
# image name op_potsdam_2_10_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_2_10_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_14_RGB_box4.tif
# image name op_potsdam_6_14_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_6_14_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_13_RGB_box4.tif
# image name op_potsdam_4_13_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_4_13_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_8_RGB_box2.tif
# image name op_potsdam_7_8_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_8_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_14_RGB_box1.tif
# image name op_potsdam_6_14_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_14_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_12_RGB_box1.tif
# image name op_potsdam_4_12_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_4_12_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_13_RGB_box3.tif
# image name op_potsdam_3_13_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_3_13_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_10_RGB_box3.tif
# image name op_potsdam_2_10_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_2_10_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_14_RGB_box2.tif
# image name op_potsdam_2_14_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_2_14_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_11_RGB_box5.tif
# image name op_potsdam_5_11_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_5_11_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_15_RGB_box5.tif
# image name op_potsdam_4_15_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_4_15_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_9_RGB_box5.tif
# image name op_potsdam_7_9_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_7_9_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_12_RGB_box3.tif
# image name op_potsdam_3_12_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_3_12_label_box3.tif
# start  2048 1024
# .....................finish
# name = train_batch, avg loss = 1.189, avg score = 1.102
# train_batch:   0%|          | 0/95 [1:47:33<?, ?it/s]
# test_batch:   0%|          | 0/19 [00:00<?, ?it/s]img in ./data/2_Ortho_RGB_test/op_potsdam_3_13_RGB_box0.tif
# image name op_potsdam_3_13_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_3_13_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_5_10_RGB_box0.tif
# image name op_potsdam_5_10_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_5_10_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_4_12_RGB_box0.tif
# image name op_potsdam_4_12_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_4_12_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_7_11_RGB_box0.tif
# image name op_potsdam_7_11_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_7_11_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_9_RGB_box0.tif
# image name op_potsdam_6_9_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_9_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_3_14_RGB_box0.tif
# image name op_potsdam_3_14_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_3_14_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_7_13_RGB_box0.tif
# image name op_potsdam_7_13_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_7_13_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_10_RGB_box0.tif
# image name op_potsdam_6_10_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_10_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_5_13_RGB_box0.tif
# image name op_potsdam_5_13_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_5_13_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_2_10_RGB_box0.tif
# image name op_potsdam_2_10_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_2_10_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_5_11_RGB_box0.tif
# image name op_potsdam_5_11_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_5_11_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_8_RGB_box0.tif
# image name op_potsdam_6_8_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_8_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_7_9_RGB_box0.tif
# image name op_potsdam_7_9_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_7_9_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_4_14_RGB_box0.tif
# image name op_potsdam_4_14_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_4_14_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_5_12_RGB_box0.tif
# image name op_potsdam_5_12_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_5_12_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_15_RGB_box0.tif
# image name op_potsdam_6_15_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_15_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_14_RGB_box0.tif
# image name op_potsdam_6_14_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_14_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_4_13_RGB_box0.tif
# image name op_potsdam_4_13_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_4_13_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_7_8_RGB_box0.tif
# image name op_potsdam_7_8_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_7_8_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_12_RGB_box0.tif
# image name op_potsdam_6_12_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_12_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_7_12_RGB_box0.tif
# image name op_potsdam_7_12_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_7_12_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_13_RGB_box0.tif
# image name op_potsdam_6_13_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_13_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_7_RGB_box0.tif
# image name op_potsdam_6_7_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_7_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_3_12_RGB_box0.tif
# image name op_potsdam_3_12_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_3_12_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_4_10_RGB_box0.tif
# image name op_potsdam_4_10_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_4_10_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_2_14_RGB_box0.tif
# image name op_potsdam_2_14_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_2_14_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_5_15_RGB_box0.tif
# image name op_potsdam_5_15_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_5_15_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_4_15_RGB_box0.tif
# image name op_potsdam_4_15_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_4_15_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_7_10_RGB_box0.tif
# image name op_potsdam_7_10_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_7_10_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_4_11_RGB_box0.tif
# image name op_potsdam_4_11_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_4_11_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_7_7_RGB_box0.tif
# image name op_potsdam_7_7_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_7_7_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_3_11_RGB_box0.tif
# image name op_potsdam_3_11_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_3_11_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_5_14_RGB_box0.tif
# image name op_potsdam_5_14_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_5_14_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_2_11_RGB_box0.tif
# image name op_potsdam_2_11_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_2_11_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_2_13_RGB_box0.tif
# image name op_potsdam_2_13_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_2_13_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_6_11_RGB_box0.tif
# image name op_potsdam_6_11_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_6_11_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_2_12_RGB_box0.tif
# image name op_potsdam_2_12_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_2_12_label_box0.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_test/op_potsdam_3_10_RGB_box0.tif
# image name op_potsdam_3_10_RGB_box0.tif
# label name ./data/labels_test/op_potsdam_3_10_label_box0.tif
# start  2048 1024
# .....................finish
# name = test_batch, avg loss = 0.870, avg score = 1.323
# test_batch:   0%|          | 0/19 [22:19<?, ?it/s]
# --- EPOCH 2/3 ---
# 1587577014.8251376
# train_batch:   0%|          | 0/95 [00:00<?, ?it/s]img in ./data/2_Ortho_RGB_train/op_potsdam_2_12_RGB_box3.tif
# image name op_potsdam_2_12_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_2_12_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_15_RGB_box2.tif
# image name op_potsdam_6_15_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_15_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_13_RGB_box2.tif
# image name op_potsdam_4_13_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_4_13_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_11_RGB_box3.tif
# image name op_potsdam_3_11_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_3_11_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_10_RGB_box1.tif
# image name op_potsdam_7_10_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_7_10_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_11_RGB_box4.tif
# image name op_potsdam_4_11_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_4_11_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_12_RGB_box5.tif
# image name op_potsdam_6_12_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_6_12_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_9_RGB_box1.tif
# image name op_potsdam_6_9_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_6_9_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_14_RGB_box1.tif
# image name op_potsdam_2_14_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_2_14_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_7_RGB_box3.tif
# image name op_potsdam_7_7_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_7_7_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_14_RGB_box4.tif
# image name op_potsdam_3_14_RGB_box4.tif
# label name ./data/labels_train/op_potsdam_3_14_label_box4.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_13_RGB_box1.tif
# image name op_potsdam_5_13_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_5_13_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_5_14_RGB_box1.tif
# image name op_potsdam_5_14_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_5_14_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_10_RGB_box5.tif
# image name op_potsdam_3_10_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_3_10_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_9_RGB_box2.tif
# image name op_potsdam_7_9_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_9_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_14_RGB_box3.tif
# image name op_potsdam_4_14_RGB_box3.tif
# label name ./data/labels_train/op_potsdam_4_14_label_box3.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_11_RGB_box1.tif
# image name op_potsdam_2_11_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_2_11_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_10_RGB_box2.tif
# image name op_potsdam_7_10_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_7_10_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_12_RGB_box2.tif
# image name op_potsdam_6_12_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_12_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_7_9_RGB_box5.tif
# image name op_potsdam_7_9_RGB_box5.tif
# label name ./data/labels_train/op_potsdam_7_9_label_box5.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_11_RGB_box2.tif
# image name op_potsdam_4_11_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_4_11_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_3_12_RGB_box1.tif
# image name op_potsdam_3_12_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_3_12_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_4_12_RGB_box1.tif
# image name op_potsdam_4_12_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_4_12_label_box1.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_6_14_RGB_box2.tif
# image name op_potsdam_6_14_RGB_box2.tif
# label name ./data/labels_train/op_potsdam_6_14_label_box2.tif
# start  2048 1024
# .....................finish
# img in ./data/2_Ortho_RGB_train/op_potsdam_2_13_RGB_box1.tif
# image name op_potsdam_2_13_RGB_box1.tif
# label name ./data/labels_train/op_potsdam_2_13_label_box1.tif
# start  2048 1024
# ..............
